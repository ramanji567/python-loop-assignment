# %% [markdown]
# <a href="https://colab.research.google.com/github/ramanji567/python-loop-assignment/blob/main/temperaturature_analysis23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Task 1 :create an array and basic math

# %%
import numpy as np
temp_celsius = np.array([22,25,28,24,26])
fahrenheit = (temp_celsius * 1.8 + 32)
avg =sum(fahrenheit)/len(fahrenheit)
print(f"celsius: {temp_celsius}")
print(f"fahrenheit: {fahrenheit}")
print(f"average fahrenheit:{avg}")
# Out:
# celsius: [22 25 28 24 26]
# fahrenheit: [71.6 77.  82.4 75.2 78.8]
# average fahrenheit:77.0

# %% [markdown]
# # Task 2:Array Shape and Statistics

# %%
test_scores = np.array([85,90,78,92,88,76,95,82,89,91,87,84])
print(f"shape:{test_scores.shape}")
print(f"total element:{test_scores.size}")
#print(f"dimension:{test_scores.ndim}")
print(f"highest score:{test_scores.max()}")
print(f"lowest score :{test_scores.min()}")
print(f"range :{test_scores.max()-test_scores.min()}")
# Out:
# shape:(12,)
# total element:12
# dimension:1
# highest score:95
# lowest score :76
# range :19

# %% [markdown]
# # Task 3: Performance comparison

# %%
import time
import numpy as np
numpy_array = np.arange(1,50001)
start_time = time.time()
numpy_sum = numpy_array.sum()
numpy_time = time.time()-start_time
#print(f"numpy time:{numpy_time:}")
python_list = list(range(1,50001))
start_time = time.time()
python_sum ={globals()['__builtins__'].sum(python_list)}
python_time = time.time()-start_time
print(f"numpy sum:{numpy_sum}")
print(f"python sum:{python_sum}")
print(f"numpy time:{numpy_time:.4f}")
print(f"python time:{python_time:.4f}")
print(f"numpy is :{python_time/numpy_time:.1f} x faster")
# Out:
# numpy sum:1250025000
# python sum:{1250025000}
# numpy time:0.0003
# python time:0.0011
# numpy is :4.1 x faster
